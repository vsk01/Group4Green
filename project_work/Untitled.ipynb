# %%
import pandas as pd

# %%
# !pwd
# Out:
# /c/Users/sasiv/Documents/PREWORK_VSK/Project 1/project_work

# %%
data_file = pd.read_csv('states_all.csv')

# %%
data_file.head()
# Out:
#        PRIMARY_KEY       STATE  YEAR  ENROLL  TOTAL_REVENUE  FEDERAL_REVENUE  \
# 0     1992_ALABAMA     ALABAMA  1992     NaN      2678885.0         304177.0
# 1      1992_ALASKA      ALASKA  1992     NaN      1049591.0         106780.0
# 2     1992_ARIZONA     ARIZONA  1992     NaN      3258079.0         297888.0
# 3    1992_ARKANSAS    ARKANSAS  1992     NaN      1711959.0         178571.0
# 4  1992_CALIFORNIA  CALIFORNIA  1992     NaN     26260025.0        2072470.0
#
#    STATE_REVENUE  LOCAL_REVENUE  TOTAL_EXPENDITURE  INSTRUCTION_EXPENDITURE  \
# 0      1659028.0       715680.0          2653798.0                1481703.0
# 1       720711.0       222100.0           972488.0                 498362.0
# 2      1369815.0      1590376.0          3401580.0                1435908.0
# 3       958785.0       574603.0          1743022.0                 964323.0
# 4     16546514.0      7641041.0         27138832.0               14358922.0
#
# ...

# %%
data_file.columns
# Out:
# Index(['PRIMARY_KEY', 'STATE', 'YEAR', 'ENROLL', 'TOTAL_REVENUE',
#        'FEDERAL_REVENUE', 'STATE_REVENUE', 'LOCAL_REVENUE',
#        'TOTAL_EXPENDITURE', 'INSTRUCTION_EXPENDITURE',
#        'SUPPORT_SERVICES_EXPENDITURE', 'OTHER_EXPENDITURE',
#        'CAPITAL_OUTLAY_EXPENDITURE', 'GRADES_PK_G', 'GRADES_KG_G',
#        'GRADES_4_G', 'GRADES_8_G', 'GRADES_12_G', 'GRADES_1_8_G',
#        'GRADES_9_12_G', 'GRADES_ALL_G', 'AVG_MATH_4_SCORE', 'AVG_MATH_8_SCORE',
#        'AVG_READING_4_SCORE', 'AVG_READING_8_SCORE'],
#       dtype='object')

# %%
# data_file[['PRIMARY_KEY']].head(2)

# %%
data_file[['PRIMARY_KEY', 'STATE', 'YEAR','TOTAL_EXPENDITURE','GRADES_PK_G', 'GRADES_KG_G','GRADES_4_G', 'GRADES_8_G', 'GRADES_12_G', 'GRADES_1_8_G','GRADES_9_12_G']].head(5)
# Out:
#        PRIMARY_KEY       STATE  YEAR  TOTAL_EXPENDITURE  GRADES_PK_G  \
# 0     1992_ALABAMA     ALABAMA  1992          2653798.0       8224.0
# 1      1992_ALASKA      ALASKA  1992           972488.0       2371.0
# 2     1992_ARIZONA     ARIZONA  1992          3401580.0       2544.0
# 3    1992_ARKANSAS    ARKANSAS  1992          1743022.0        808.0
# 4  1992_CALIFORNIA  CALIFORNIA  1992         27138832.0      59067.0
#
#    GRADES_KG_G  GRADES_4_G  GRADES_8_G  GRADES_12_G  GRADES_1_8_G  \
# 0      55460.0     57948.0     58025.0      41167.0      471564.0
# 1      10152.0      9748.0      8789.0       6714.0       79117.0
# 2      53497.0     55433.0     49081.0      37410.0      437127.0
# 3      33511.0     34632.0     36011.0      27651.0      281338.0
# 4     431763.0    418418.0    363296.0     270675.0     3286034.0
#
#    GRADES_9_12_G
# 0       196386.0
# 1        30847.0
# 2       175210.0
# 3       123113.0
# 4      1372011.0

# %%
data_file.STATE.nunique()
# Out:
# 80

# %%
data_file[['STATE','TOTAL_REVENUE','YEAR']]
# Out:
#                      STATE  TOTAL_REVENUE  YEAR
# 0                  ALABAMA      2678885.0  1992
# 1                   ALASKA      1049591.0  1992
# 2                  ARIZONA      3258079.0  1992
# 3                 ARKANSAS      1711959.0  1992
# 4               CALIFORNIA     26260025.0  1992
# 5                 COLORADO      3185173.0  1992
# 6              CONNECTICUT      3834302.0  1992
# 7                 DELAWARE       645233.0  1992
# 8     DISTRICT_OF_COLUMBIA       709480.0  1992
# 9                  FLORIDA     11506299.0  1992
# 10                 GEORGIA      5536901.0  1992
# 11                  HAWAII       996809.0  1992
# 12                   IDAHO       859329.0  1992
# 13                ILLINOIS      9748650.0  1992
# 14                 INDIANA      5060274.0  1992
# 15                    IOWA      2663934.0  1992
# 16                  KANSAS      2245348.0  1992
# 17                KENTUCKY      2642902.0  1992
# 18               LOUISIANA      3341253.0  1992
# ...

# %%
dfstate_year=dfstate_year.drop_duplicates(subset=['PRIMARY_KEY'],keep=False)

# %%
dfstate_year = data_file[['PRIMARY_KEY','STATE','TOTAL_EXPENDITURE','YEAR','GRADES_ALL_G']].dropna(axis=0,how='any')

# %%
dfstate_year['EXP_PER_STUDENT'] = dfstate_year['TOTAL_EXPENDITURE']/dfstate_year['GRADES_ALL_G']

# %%
df_sort = dfstate_year.sort_values(by=['EXP_PER_STUDENT'],ascending=False)

# %%
df_sort.head(5)
# Out:
#                     PRIMARY_KEY                 STATE  TOTAL_EXPENDITURE  \
# 864               2008_VIRGINIA              VIRGINIA         15236306.0
# 863               2008_VIRGINIA              VIRGINIA         15236306.0
# 824   2008_DISTRICT_OF_COLUMBIA  DISTRICT_OF_COLUMBIA          1224785.0
# 1210              2015_NEW_YORK              NEW_YORK         65094591.0
# 1159              2014_NEW_YORK              NEW_YORK         62556193.0
#
#       YEAR  GRADES_ALL_G  EXP_PER_STUDENT
# 864   2008       24554.0       620.522359
# 863   2008       51345.0       296.743714
# 824   2008       36676.0        33.394727
# 1210  2015     2471847.0        26.334393
# 1159  2014     2492829.0        25.094458

# %%
df_sort.PRIMARY_KEY.unique()
# Out:
# array(['2008_VIRGINIA', '2008_DISTRICT_OF_COLUMBIA', '2015_NEW_YORK', ...,
#        '1994_OKLAHOMA', '1993_MISSISSIPPI', '1993_OKLAHOMA'], dtype=object)

# %%
dfstate_year.groupby['STATE','EXP_PER_STUDENT'].mean() # by expenditure
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-162-5d3a5a307525> in <module>
# ----> 1 dfstate_year.groupby['STATE','EXP_PER_STUDENT'].mean() #.nlargest(5) # by expenditure
#
# TypeError: 'method' object is not subscriptable

# %%
dfstate_year['EXP_PER_STUDENT']
# Out:
# 0        3.924726
# 1        8.657035
# 2        5.532095
# 3        4.301008
# 4        5.753273
# 5        5.802969
# 6        8.516973
# 7        6.633547
# 8       10.612757
# 9        6.212895
# 10       5.003377
# 11       6.858740
# 12       4.134274
# 13       5.983050
# 14       5.867650
# 15       6.314537
# 16       5.484535
# 17       4.216487
# 18       4.814792
# 19       6.273517
# 20       6.924669
# 21       6.750608
# 22       7.270999
# 23       6.807066
# 24       3.743457
# 25       5.342348
# 26       5.308400
# 27       5.887926
# 28       6.125635
# 29       6.184214
#           ...
# 1198    17.041018
# 1199    18.954357
# 1200    12.502195
# 1201    14.947523
# 1202    10.469082
# 1203    12.369738
# 1204    13.487382
# 1205    14.638621
# 1206     9.678765
# 1207    17.782502
# 1208    22.946503
# 1209    12.368700
# 1210    26.334393
# 1211     9.852734
# 1212    18.099203
# 1213    14.167597
# 1214     9.696901
# 1216    18.596869
# 1217    17.609187
# ...
